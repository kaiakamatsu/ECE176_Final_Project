# %% [markdown]
# # ECE176: Pneumonia Detection, CNN

# %% [markdown]
# ## Introduction

# %% [markdown]
# **In this report, we aim to address the following questions:**
#
# 1. How accurately can we distinguish healthy and pneumonia patients with our CNN?
#
# 2. Which CNN architecture performs best for this task?
#
# 3. Can we use pre-trained CNNs to create a more accurate model?

# %% [markdown]
# ## Dataset

# %% [markdown]
# [Collection of Chest X Ray of Healthy vs Pneumonia affected patients](https://www.kaggle.com/datasets/praveengovi/coronahack-chest-xraydataset)

# %% [markdown]
# ## Import Packages and Prepare GPU

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torch.nn.functional as F

import torchvision.datasets as dset
import torchvision.transforms as T
import torchvision

import numpy as np
import os
import pandas as pd
import shutil
import matplotlib.pyplot as plt

# %%
USE_GPU = True
num_class = 100
dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cuda

# %% [markdown]
# ## Load Dataset With Augmentations

# %% [markdown]
# We first need to split the images based on labeled classes to use the Dataloader.
#
# **Note: This only needs to be run one time**

# %%
# first read in the metadata file
data = pd.read_csv("Chest_xray_Corona_Metadata.csv")
data.head(10)
# Out:
#    Unnamed: 0   X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0           0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1           1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2           2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3           3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4           4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
# 5           5  IM-0117-0001.jpeg  Normal        TRAIN                    NaN
# 6           6  IM-0115-0001.jpeg  Normal        TRAIN                    NaN
# 7           7  IM-0189-0001.jpeg  Normal        TRAIN                    NaN
# 8           8  IM-0187-0001.jpeg  Normal        TRAIN                    NaN
# 9           9  IM-0185-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN

# %%
print(set(data['Label']))
# Out:
# {'Pnemonia', 'Normal'}

# %%
# subdirectories for each class
#os.mkdir("Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia")
#os.mkdir("Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Normal")
#os.mkdir("Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia")
#os.mkdir("Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Normal")

# %%
path_train = "Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train"
path_test = "Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test"

train_num = len(os.listdir(path_train))
print("Train data: " + str(train_num))
test_num = len(os.listdir(path_test))
print("Test data: " + str(test_num))
# Out:
# Train data: 5311
# Test data: 626

# %%
# ONLY NEED TO RUN ONCE

normal_train = 0
pnemonia_train = 0
normal_test = 0
pnemonia_test = 0

# "X_ray_image_name" = name of file
# "Label" = pneumonia or normal
# "Dataset_type" = train or test

for i in range(data.shape[0]):
    if data["Dataset_type"][i] == "TRAIN":
        if data["Label"][i] == "Normal":
            shutil.copy(path_train + "/" + data["X_ray_image_name"][i], path_train + "/Normal/" + data["X_ray_image_name"][i])
            normal_train = normal_train + 1
        else:
            shutil.copy(path_train + "/" + data["X_ray_image_name"][i], path_train + "/Pnemonia/" + data["X_ray_image_name"][i])
            pnemonia_train = pnemonia_train + 1
    elif data["Dataset_type"][i] == "TEST":
        if data["Label"][i] == "Normal":
            shutil.copy(path_test + "/" + data["X_ray_image_name"][i], path_test + "/Normal/" + data["X_ray_image_name"][i])
            normal_test = normal_test + 1
        else:
            shutil.copy(path_test + "/" + data["X_ray_image_name"][i], path_test + "/Pnemonia/" + data["X_ray_image_name"][i])
            pnemonia_test = pnemonia_test + 1

print(
    "X-ray of Normal patients (TRAIN DATASET): " + str(normal_train) + "\n",
    "X-ray of Infected patients (TRAIN DATASET): " + str(pnemonia_train) + "\n",
    "X-ray of Normal patients (TEST DATASET): " + str(normal_test) + "\n",
    "X-ray of Infected patients (TEST DATASET): " + str(pnemonia_test) + "\n"
)
# Out:
# X-ray of Normal patients (TRAIN DATASET): 1342
#  X-ray of Infected patients (TRAIN DATASET): 3944
#  X-ray of Normal patients (TEST DATASET): 234
#  X-ray of Infected patients (TEST DATASET): 390

# %%
# redefine number of train test 
train_num = normal_train + pnemonia_train
print("Train data: " + str(train_num))
test_num = normal_test + pnemonia_test
print("Test data: " + str(test_num))
# Out:
# Train data: 5286
# Test data: 624

# %%
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import datasets as dset
from torchvision import transforms as T
from torch.utils.data import sampler

train_data_path = "Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/"
test_data_path = "Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/"
batch_size = 32

# Data augmentation
transform_train = T.Compose([
    T.Resize(256),
    T.RandomHorizontalFlip(),  # Horizontal flips
    T.RandomVerticalFlip(),
    T.CenterCrop(256),  # Crops
    T.ToTensor(),
    T.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))  # Hard coded mean and std rgb values
])

transform_test = T.Compose([
    T.Resize(256),
    T.CenterCrop(256),
    T.ToTensor(),
    T.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))  # Hard coded mean and std rgb values
])

# Load the datasets
full_train_data = dset.ImageFolder(root=train_data_path, transform=transform_train)

# Splitting the dataset
train_size = int(0.8 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_dataset, val_dataset = random_split(full_train_data, [train_size, val_size])

# Data loaders
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_data_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_data = dset.ImageFolder(root=test_data_path, transform=transform_test)
test_data_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# # Visualize Data

# %% [markdown]
# ### Counting the number of images in each class

# %% [markdown]
# In this dataset, we categorize the images into two classes: 'Normal' and 'Pneumonia.' In the plot below, 'Normal' instances are colored red, while 'Pneumonia' cases are green.

# %%
# Count number of images in each class
class_counts = data['Label'].value_counts()

# Specify colors for each class
colors = ['red' if label == 'Normal' else 'green' for label in class_counts.index]

# Plotting
plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=colors)
plt.title('Count of Normal vs Pneumonia Cases')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Keep the class names horizontal for readability
plt.show()
print(class_counts)
# Out:
# Label
# Pnemonia    4334
# Normal      1576
# Name: count, dtype: int64

# %% [markdown]
# It is important for us to make sure that our training and testing folds have similar ratios of normal and pneumonia images.

# %%
train_test_grouped = data.groupby('Dataset_type')

for name, group in train_test_grouped:
    # Count number of images in each class
    class_counts = group['Label'].value_counts()

    # Specify colors for each class
    colors = ['red' if label == 'Normal' else 'green' for label in class_counts.index]

    # Plotting
    plt.figure(figsize=(8, 6))
    class_counts.plot(kind='bar', color=colors)
    plt.title( name + ': Count of Normal vs Pneumonia Cases')
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.xticks(rotation=0)  # Keep the class names horizontal for readability
    plt.show()
    print(class_counts)
# Out:
# Label
# Pnemonia    390
# Normal      234
# Name: count, dtype: int64
# Label
# Pnemonia    3944
# Normal      1342
# Name: count, dtype: int64

# %% [markdown]
# > This shows that our model will be training and testing on similar ratios of case and control images.

# %% [markdown]
# ### Visualizing the chest X-rays

# %%
import matplotlib.pyplot as plt
import numpy as np

def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean= np.array([0.5071, 0.4867, 0.4408])
    std=np.array([0.2675, 0.2565, 0.2761])
    inp = std * inp + mean  # unnormalize
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize=(10, 5))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# %% [markdown]
# Visualizing the input images from the training data:

# %%
import torchvision

# Load a batch of images and their corresponding labels from the train_data_loader
batch_images, batch_labels = next(iter(train_data_loader))

# Randomly select a subset of data from the loaded batch
num_samples = 5  # Define how many samples you want to visualize
random_indices = torch.randperm(len(batch_images))[:num_samples]  # Get random indices
selected_images = batch_images[random_indices]
selected_labels = batch_labels[random_indices]

# Create a grid layout for the selected images
image_grid = torchvision.utils.make_grid(selected_images)

# Generate titles (labels) for the selected images
label_titles = ', '.join([full_train_data.classes[label] for label in selected_labels])

# Display the images and their titles
imshow(image_grid, title=label_titles)

# %% [markdown]
# Visualizing the input images from the testing data:

# %%
import torchvision

# Load a batch of images and their corresponding labels from the train_data_loader
batch_images, batch_labels = next(iter(test_data_loader))

# Randomly select a subset of data from the loaded batch
num_samples = 5  # Define how many samples you want to visualize
random_indices = torch.randperm(len(batch_images))[:num_samples]  # Get random indices
selected_images = batch_images[random_indices]
selected_labels = batch_labels[random_indices]

# Create a grid layout for the selected images
image_grid = torchvision.utils.make_grid(selected_images)

# Generate titles (labels) for the selected images
label_titles = ', '.join([test_data.classes[label] for label in selected_labels])

# Display the images and their titles
imshow(image_grid, title=label_titles)

# %% [markdown]
# > In this section, we visualized 5 random images from the training and testing set. We can see that the inflammation of the lungs is visible in these chest X-rays for patients with pneumonia.

# %% [markdown]
# # Define Training and Testing functions

# %%
def flatten(x):
    N = x.shape[0] 
    return x.view(N, -1)

# %%
# create a function for model testing 
def check_accuracy(loader, model, dataset):
    print('Checking accuracy ' + dataset)
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device=device, dtype=dtype), y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %%
def train_test_model(model, train_data_loader, val_data_loader, test_data_loader, optimizer, epochs=10, print_every=50, device='cuda', use_early_stop=True, patience=5, use_scheduler=False):
    """
    Train and test a model, with optional early stopping based on validation accuracy and optional learning rate scheduling.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - train_data_loader: Data loader for the training set.
    - val_data_loader: Data loader for the validation set.
    - test_data_loader: Data loader for the test set.
    - optimizer: An Optimizer object we will use to train the model.
    - epochs: (Optional) Number of epochs to train the model.
    - print_every: (Optional) Number of iterations before printing loss and checking accuracy.
    - device: (Optional) Device to run the model on ('cuda' or 'cpu').
    - use_early_stop: (Optional) Whether to use early stopping.
    - patience: (Optional) Number of epochs to wait for improvement before stopping.
    - use_scheduler: (Optional) Whether to use learning rate scheduler.
    
    Returns: A tuple of lists containing training, validation, and test accuracies at each print iteration.
    """
    train_accuracies, val_accuracies, test_accuracies = [], [], []
    best_val_acc = 0
    epochs_no_improve = 0
    
    # Initialize scheduler if use_scheduler is True
    scheduler = None
    if use_scheduler:
        scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

    for e in range(epochs):
        model.train()  # Set model to training mode
        for t, (x, y) in enumerate(train_data_loader):
            x, y = x.to(device=device), y.to(device=device, dtype=torch.long)

            # Forward pass
            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if (t + 1) % print_every == 0:
                print(f'Epoch {e}, Iteration {t + 1}, loss = {loss.item():.4f}')
                # Check accuracy on the training set
                train_acc = check_accuracy(train_data_loader, model, 'training')
                train_accuracies.append(train_acc)
                
                # Check accuracy on the validation set
                val_acc = check_accuracy(val_data_loader, model, 'validation')
                val_accuracies.append(val_acc)
                
                # Check accuracy on testing set 
                test_acc = check_accuracy(test_data_loader, model, 'test')
                test_accuracies.append(test_acc)
                
                # Early stopping logic
                if use_early_stop:
                    if val_acc > best_val_acc:
                        best_val_acc = val_acc
                        epochs_no_improve = 0
                    else:
                        epochs_no_improve += 1
                        if epochs_no_improve == patience:
                            print(f'Early stopping triggered after {e+1} epochs.')
                            final_test_acc = check_accuracy(test_data_loader, model, 'final test')
                            print(f'Final Test Accuracy: {final_test_acc:.2f}')
                            return train_accuracies, val_accuracies, test_accuracies
                print(f'Training Accuracy: {train_acc:.2f}, Validation Accuracy: {val_acc:.2f}')
        
        # Learning rate scheduler step
        if use_scheduler and scheduler is not None:
            scheduler.step()

    # Final testing accuracy after all epochs
    final_test_acc = check_accuracy(test_data_loader, model, 'final test')
    print(f'Final Test Accuracy: {final_test_acc:.2f}')
    
    return train_accuracies, val_accuracies, test_accuracies

# %% [markdown]
# # Simple CNN

# %% [markdown]
# ### Defining the simple CNN architecture

# %%
# Define the CNN architecture
class PneumoniaSimpleCNN(nn.Module):
    def __init__(self, num_classes=2):  # 2 classes: Normal, Pneumonia
        super(PneumoniaSimpleCNN, self).__init__()
        # Define layers of a CNN
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)  
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        
        self.fc1 = nn.Linear(64 * 64 * 64, 512)  
        self.fc2 = nn.Linear(512, num_classes)
        
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        
    def forward(self, x):
        
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        # Flatten the layer
        x = flatten(x)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Train and Test the Simple CNN model

# %%
from torch.optim import lr_scheduler

num_classes = 2  # Normal, Pneumonia
learning_rate = 0.001
num_epochs = 10

# Define the model 
model = PneumoniaSimpleCNN(num_classes).to(device)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-4)

# Train the model
train_accuracies, val_accuracies, test_accuracies = train_test_model(model,
                                                     train_data_loader,
                                                     val_data_loader, 
                                                     test_data_loader, 
                                                     optimizer, 
                                                     epochs=10,
                                                     print_every=50,
                                                     device='cuda',
                                                     use_early_stop=True,
                                                     patience=5, 
                                                     use_scheduler=True)
# Out:
# Epoch 0, Iteration 50, loss = 0.1996
# Checking accuracy training
# Got 3926 / 4228 correct (92.86)
# Checking accuracy validation
# Got 977 / 1058 correct (92.34)
# Checking accuracy test
# Got 459 / 624 correct (73.56)
# Training Accuracy: 0.93, Validation Accuracy: 0.92
# Epoch 0, Iteration 100, loss = 0.0589
# Checking accuracy training
# Got 3973 / 4228 correct (93.97)
# Checking accuracy validation
# Got 992 / 1058 correct (93.76)
# Checking accuracy test
# Got 468 / 624 correct (75.00)
# Training Accuracy: 0.94, Validation Accuracy: 0.94
# Epoch 1, Iteration 50, loss = 0.0980
# Checking accuracy training
# Got 4011 / 4228 correct (94.87)
# Checking accuracy validation
# Got 999 / 1058 correct (94.42)
# Checking accuracy test
# Got 469 / 624 correct (75.16)
# Training Accuracy: 0.95, Validation Accuracy: 0.94
# Epoch 1, Iteration 100, loss = 0.0705
# Checking accuracy training
# Got 4057 / 4228 correct (95.96)
# Checking accuracy validation
# Got 1000 / 1058 correct (94.52)
# Checking accuracy test
# Got 464 / 624 correct (74.36)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 2, Iteration 50, loss = 0.0782
# Checking accuracy training
# Got 4006 / 4228 correct (94.75)
# Checking accuracy validation
# Got 991 / 1058 correct (93.67)
# Checking accuracy test
# Got 454 / 624 correct (72.76)
# Training Accuracy: 0.95, Validation Accuracy: 0.94
# Epoch 2, Iteration 100, loss = 0.0649
# Checking accuracy training
# Got 4058 / 4228 correct (95.98)
# Checking accuracy validation
# Got 1004 / 1058 correct (94.90)
# Checking accuracy test
# Got 481 / 624 correct (77.08)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 3, Iteration 50, loss = 0.1716
# Checking accuracy training
# Got 4079 / 4228 correct (96.48)
# Checking accuracy validation
# Got 1023 / 1058 correct (96.69)
# Checking accuracy test
# Got 481 / 624 correct (77.08)
# Training Accuracy: 0.96, Validation Accuracy: 0.97
# Epoch 3, Iteration 100, loss = 0.0378
# Checking accuracy training
# Got 4085 / 4228 correct (96.62)
# Checking accuracy validation
# Got 1016 / 1058 correct (96.03)
# Checking accuracy test
# Got 479 / 624 correct (76.76)
# Training Accuracy: 0.97, Validation Accuracy: 0.96
# Epoch 4, Iteration 50, loss = 0.2206
# Checking accuracy training
# Got 4108 / 4228 correct (97.16)
# Checking accuracy validation
# Got 1015 / 1058 correct (95.94)
# Checking accuracy test
# Got 467 / 624 correct (74.84)
# Training Accuracy: 0.97, Validation Accuracy: 0.96
# Epoch 4, Iteration 100, loss = 0.1010
# Checking accuracy training
# Got 4104 / 4228 correct (97.07)
# Checking accuracy validation
# Got 1015 / 1058 correct (95.94)
# Checking accuracy test
# Got 458 / 624 correct (73.40)
# Training Accuracy: 0.97, Validation Accuracy: 0.96
# Epoch 5, Iteration 50, loss = 0.1273
# Checking accuracy training
# Got 4107 / 4228 correct (97.14)
# Checking accuracy validation
# Got 1016 / 1058 correct (96.03)
# Checking accuracy test
# Got 458 / 624 correct (73.40)
# Training Accuracy: 0.97, Validation Accuracy: 0.96
# Epoch 5, Iteration 100, loss = 0.1629
# Checking accuracy training
# Got 4122 / 4228 correct (97.49)
# Checking accuracy validation
# Got 1013 / 1058 correct (95.75)
# Checking accuracy test
# Got 466 / 624 correct (74.68)
# Early stopping triggered after 6 epochs.
# Checking accuracy final test
# Got 466 / 624 correct (74.68)
# Final Test Accuracy: 0.75

# %% [markdown]
# ### Visualize the image, true labels, and predicted labels

# %%
def imshow(img):
    img = img.cpu().numpy().transpose((1, 2, 0))  # convert from Tensor image
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = std * img + mean  # Unnormalize
    img = np.clip(img, 0, 1)  # Clip values to [0, 1] range
    plt.imshow(img)
    plt.show()

# Assuming test_data_loader has batch_size at least 5 or adjust as necessary
# Get a batch of test images and labels
dataiter = iter(test_data_loader)
images, labels = next(dataiter)

# Select random 5 indices
idx = np.random.choice(images.size(0), 5, replace=False)

# Select random images and labels
random_images = images[idx]
random_labels = labels[idx]

# Move tensors to the configured device
random_images, random_labels = random_images.to(device), random_labels.to(device)

# Get predictions
model.eval()  # Make sure model is in eval mode
with torch.no_grad():
    outputs = model(random_images)
    _, predicted = torch.max(outputs, 1)

# Show images
imshow(torchvision.utils.make_grid(random_images.cpu()))
# Print true and predicted labels
print('True labels: ', ' '.join(f'{test_data.classes[random_labels[j].item()]}' for j in range(len(random_labels))))
print('Predicted: ', ' '.join(f'{test_data.classes[predicted[j].item()]}' for j in range(len(predicted))))
# Out:
# True labels:  Normal Normal Normal Normal Normal
# Predicted:  Pnemonia Normal Normal Pnemonia Normal

# %% [markdown]
# ### Visualize accuracy over epochs

# %%
actual_epochs = len(train_accuracies)  # Assuming this reflects the actual number of epochs run
epochs = [i / 2 for i in range(0, actual_epochs)]

# Now, we'll plot the accuracies.
plt.figure(figsize=[10,5])
plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='o')
plt.plot(epochs, test_accuracies, label='Test Accuracy', marker='o')
plt.title('Model Accuracies per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > Note: Since we are performing binary classification and 62.5% of the testing dataset is pneumonia, we are expecting a testing accuracy much larger than 62.5%.

# %% [markdown]
# # Resnet CNN

# %% [markdown]
# ### Can Resnet CNN be applied to classify chest X-rays?

# %% [markdown]
# ### Define the Resnet Architecture

# %%
class ResNetBlocks(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1, downsample=None, batchnorm=True):
        super(ResNetBlocks, self).__init__()
        
        self.downsample = downsample
        self.relu = nn.ReLU(inplace=True) #relu
        self.out_channels = out_channels
        
        self.conv_1 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, (3,3), stride=stride, padding = 1),
            nn.ReLU(inplace=True)
        )
        if batchnorm:
            self.conv_1 = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, (3,3), stride=stride, padding = 1), 
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True)
                )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(out_channels, out_channels, (3,3), stride=1, padding = 1)
        )
        if batchnorm:
            self.conv_2 = nn.Sequential(
                nn.Conv2d(out_channels, out_channels, (3,3), stride=1, padding = 1), 
                nn.BatchNorm2d(out_channels)
            )
        
    def forward(self, x):
        resid=x
        out = self.conv_1(x)
        out = self.conv_2(out)
        if self.downsample:
            resid=self.downsample(x)
        out = out + resid
        out = self.relu(out)
        return out
        
    
class ResNet(nn.Module):
    
    def __init__(self, block, num_blocks, batchnorm=True):
        super(ResNet, self).__init__()
        
        self.inchannel=64 # current channel size, used later for skips 
        
        self.convlayer_1 = nn.Sequential(
            nn.Conv2d(3, 64, (7,7), stride=2, padding=3),
            nn.ReLU(inplace=True)
        )
        
        if batchnorm:
            self.convlayer_1 = nn.Sequential(
                nn.Conv2d(3, 64, (7,7), stride=2, padding=3),
                nn.BatchNorm2d(64),
                nn.ReLU(inplace=True)
            )
        
        self.maxpool = nn.MaxPool2d((3,3), stride=2, padding = 1)
        
        self.block1 = self.make_layer(block, 64, num_blocks[0], stride = 1)
        self.block2 = self.make_layer(block, 128, num_blocks[1], stride = 1)
        self.block3 = self.make_layer(block, 256, num_blocks[2], stride = 1)
        self.block4 = self.make_layer(block, 512, num_blocks[3], stride = 2)
        
        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear( 512, num_class) 
        #nn.init.kaiming_normal_(self.fc.weight)
    
    def make_layer(self, block, channel, numblocks, stride=1, batchnorm=True):
        downsample = None
        if self.inchannel != channel:
            downsample = nn.Sequential(
                nn.Conv2d(self.inchannel, channel, (1,1), stride=stride) # add skip arrow
            )
            if batchnorm:
                downsample = nn.Sequential(
                    nn.Conv2d(self.inchannel, channel, (1,1), stride=stride), # add skip arrow
                    nn.BatchNorm2d(channel)
                )
            
        layers = []
        layers.append(block(self.inchannel, channel, stride, downsample))
        self.inchannel = channel #update current channel
        
        # add number of blocks here 
        for j in range(1,numblocks): # if we want to add 2 blocks, this for loop will run once 
            layers.append(block(self.inchannel, channel))
            
        return nn.Sequential(*layers)
    
        
    def forward(self, x):
        x = self.convlayer_1(x)
        x = self.maxpool(x)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.avgpool(x)
        x = flatten(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ### Train and Test the model

# %%
num_classes = 2  # Normal, Pneumonia
learning_rate = 0.0001
num_epochs = 7

# Define the model 
model = ResNet(ResNetBlocks, [2,2,2,2]).to(device)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
train_accuracies, val_accuracies, test_accuracies = train_test_model(model,
                                                     train_data_loader,
                                                     val_data_loader, 
                                                     test_data_loader, 
                                                     optimizer, 
                                                     epochs=10,
                                                     print_every=50,
                                                     device='cuda',
                                                     use_early_stop=True,
                                                     patience=5, 
                                                     use_scheduler=False)
# Out:
# Epoch 0, Iteration 50, loss = 0.3501
# Checking accuracy training
# Got 3820 / 4228 correct (90.35)
# Checking accuracy validation
# Got 957 / 1058 correct (90.45)
# Checking accuracy test
# Got 457 / 624 correct (73.24)
# Training Accuracy: 0.90, Validation Accuracy: 0.90
# Epoch 0, Iteration 100, loss = 0.2792
# Checking accuracy training
# Got 3754 / 4228 correct (88.79)
# Checking accuracy validation
# Got 936 / 1058 correct (88.47)
# Checking accuracy test
# Got 471 / 624 correct (75.48)
# Training Accuracy: 0.89, Validation Accuracy: 0.88
# Epoch 1, Iteration 50, loss = 0.3405
# Checking accuracy training
# Got 3902 / 4228 correct (92.29)
# Checking accuracy validation
# Got 973 / 1058 correct (91.97)
# Checking accuracy test
# Got 495 / 624 correct (79.33)
# Training Accuracy: 0.92, Validation Accuracy: 0.92
# Epoch 1, Iteration 100, loss = 0.1332
# Checking accuracy training
# Got 3754 / 4228 correct (88.79)
# Checking accuracy validation
# Got 929 / 1058 correct (87.81)
# Checking accuracy test
# Got 516 / 624 correct (82.69)
# Training Accuracy: 0.89, Validation Accuracy: 0.88
# Epoch 2, Iteration 50, loss = 0.1034
# Checking accuracy training
# Got 3904 / 4228 correct (92.34)
# Checking accuracy validation
# Got 973 / 1058 correct (91.97)
# Checking accuracy test
# Got 498 / 624 correct (79.81)
# Training Accuracy: 0.92, Validation Accuracy: 0.92
# Epoch 2, Iteration 100, loss = 0.2791
# Checking accuracy training
# Got 3777 / 4228 correct (89.33)
# Checking accuracy validation
# Got 952 / 1058 correct (89.98)
# Checking accuracy test
# Got 476 / 624 correct (76.28)
# Training Accuracy: 0.89, Validation Accuracy: 0.90
# Epoch 3, Iteration 50, loss = 0.2218
# Checking accuracy training
# Got 3958 / 4228 correct (93.61)
# Checking accuracy validation
# Got 980 / 1058 correct (92.63)
# Checking accuracy test
# Got 513 / 624 correct (82.21)
# Training Accuracy: 0.94, Validation Accuracy: 0.93
# Epoch 3, Iteration 100, loss = 0.4832
# Checking accuracy training
# Got 3906 / 4228 correct (92.38)
# Checking accuracy validation
# Got 960 / 1058 correct (90.74)
# Checking accuracy test
# Got 514 / 624 correct (82.37)
# Training Accuracy: 0.92, Validation Accuracy: 0.91
# Epoch 4, Iteration 50, loss = 0.1587
# Checking accuracy training
# Got 3961 / 4228 correct (93.68)
# Checking accuracy validation
# Got 971 / 1058 correct (91.78)
# Checking accuracy test
# Got 523 / 624 correct (83.81)
# Training Accuracy: 0.94, Validation Accuracy: 0.92
# Epoch 4, Iteration 100, loss = 0.3354
# Checking accuracy training
# Got 3849 / 4228 correct (91.04)
# Checking accuracy validation
# Got 939 / 1058 correct (88.75)
# Checking accuracy test
# Got 524 / 624 correct (83.97)
# Training Accuracy: 0.91, Validation Accuracy: 0.89
# Epoch 5, Iteration 50, loss = 0.0650
# Checking accuracy training
# Got 4008 / 4228 correct (94.80)
# Checking accuracy validation
# Got 991 / 1058 correct (93.67)
# Checking accuracy test
# Got 480 / 624 correct (76.92)
# Training Accuracy: 0.95, Validation Accuracy: 0.94
# Epoch 5, Iteration 100, loss = 0.0370
# Checking accuracy training
# Got 3812 / 4228 correct (90.16)
# Checking accuracy validation
# Got 928 / 1058 correct (87.71)
# Checking accuracy test
# Got 521 / 624 correct (83.49)
# Training Accuracy: 0.90, Validation Accuracy: 0.88
# Epoch 6, Iteration 50, loss = 0.0787
# Checking accuracy training
# Got 4037 / 4228 correct (95.48)
# Checking accuracy validation
# Got 1000 / 1058 correct (94.52)
# Checking accuracy test
# Got 481 / 624 correct (77.08)
# Training Accuracy: 0.95, Validation Accuracy: 0.95
# Epoch 6, Iteration 100, loss = 0.2194
# Checking accuracy training
# Got 3989 / 4228 correct (94.35)
# Checking accuracy validation
# Got 997 / 1058 correct (94.23)
# Checking accuracy test
# Got 483 / 624 correct (77.40)
# Training Accuracy: 0.94, Validation Accuracy: 0.94
# Epoch 7, Iteration 50, loss = 0.0769
# Checking accuracy training
# Got 4056 / 4228 correct (95.93)
# Checking accuracy validation
# Got 1002 / 1058 correct (94.71)
# Checking accuracy test
# Got 506 / 624 correct (81.09)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 7, Iteration 100, loss = 0.1453
# Checking accuracy training
# Got 3737 / 4228 correct (88.39)
# Checking accuracy validation
# Got 934 / 1058 correct (88.28)
# Checking accuracy test
# Got 415 / 624 correct (66.51)
# Training Accuracy: 0.88, Validation Accuracy: 0.88
# Epoch 8, Iteration 50, loss = 0.1853
# Checking accuracy training
# Got 4068 / 4228 correct (96.22)
# Checking accuracy validation
# Got 1004 / 1058 correct (94.90)
# Checking accuracy test
# Got 498 / 624 correct (79.81)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 8, Iteration 100, loss = 0.1385
# Checking accuracy training
# Got 4035 / 4228 correct (95.44)
# Checking accuracy validation
# Got 1003 / 1058 correct (94.80)
# Checking accuracy test
# Got 458 / 624 correct (73.40)
# Training Accuracy: 0.95, Validation Accuracy: 0.95
# Epoch 9, Iteration 50, loss = 0.0657
# Checking accuracy training
# Got 4051 / 4228 correct (95.81)
# Checking accuracy validation
# Got 1005 / 1058 correct (94.99)
# Checking accuracy test
# Got 518 / 624 correct (83.01)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 9, Iteration 100, loss = 0.0792
# Checking accuracy training
# Got 4019 / 4228 correct (95.06)
# Checking accuracy validation
# Got 1009 / 1058 correct (95.37)
# Checking accuracy test
# Got 462 / 624 correct (74.04)
# Training Accuracy: 0.95, Validation Accuracy: 0.95
# Checking accuracy final test
# Got 519 / 624 correct (83.17)
# Final Test Accuracy: 0.83

# %% [markdown]
# ### Visualize the Accuracy Over Epochs

# %%
actual_epochs = len(train_accuracies)  # Assuming this reflects the actual number of epochs run
epochs = [i / 2 for i in range(0, actual_epochs)]


plt.figure(figsize=[10,5])
plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='o')
plt.plot(epochs, test_accuracies, label='Test Accuracy', marker='o')
plt.title('Model Accuracies per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # VGG 16

# %% [markdown]
# ### Can VGG 16 be applied to classify chest X-rays?

# %% [markdown]
# ### Define the VGG 16 Architecture

# %%
class VGG16(nn.Module):
    def __init__(self, num_classes=2):  # Default for ImageNet
        super(VGG16, self).__init__()
        # Convolutional layers
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Block 4
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Block 5
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        # Fully connected layers
        self.classifier = nn.Sequential(
            nn.Linear(512 * 8 * 8, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(4096, num_classes)  # num_classes is the number of your final output classes
        )

    def forward(self, x):
        x = self.features(x)
        #print(x.shape)  # Add this line to check the output size
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %% [markdown]
# ### Train and Test the model

# %%
learning_rate = 0.001
num_epochs = 10

model = VGG16(num_classes=2).to(device)  # Specify your number of classes
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Train the model
train_accuracies, val_accuracies, test_accuracies = train_test_model(model,
                                                     train_data_loader,
                                                     val_data_loader, 
                                                     test_data_loader, 
                                                     optimizer, 
                                                     epochs=10,
                                                     print_every=50,
                                                     device='cuda',
                                                     use_early_stop=True,
                                                     patience=5, 
                                                     use_scheduler=False)
# Out:
# Epoch 0, Iteration 50, loss = 0.5439
# Checking accuracy training
# Got 3150 / 4228 correct (74.50)
# Checking accuracy validation
# Got 794 / 1058 correct (75.05)
# Checking accuracy test
# Got 390 / 624 correct (62.50)
# Training Accuracy: 0.75, Validation Accuracy: 0.75
# Epoch 0, Iteration 100, loss = 0.6188
# Checking accuracy training
# Got 3150 / 4228 correct (74.50)
# Checking accuracy validation
# Got 794 / 1058 correct (75.05)
# Checking accuracy test
# Got 390 / 624 correct (62.50)
# Training Accuracy: 0.75, Validation Accuracy: 0.75
# Epoch 1, Iteration 50, loss = 0.3285
# Checking accuracy training
# Got 3589 / 4228 correct (84.89)
# Checking accuracy validation
# Got 899 / 1058 correct (84.97)
# Checking accuracy test
# Got 464 / 624 correct (74.36)
# Training Accuracy: 0.85, Validation Accuracy: 0.85
# Epoch 1, Iteration 100, loss = 0.4651
# Checking accuracy training
# Got 3150 / 4228 correct (74.50)
# Checking accuracy validation
# Got 794 / 1058 correct (75.05)
# Checking accuracy test
# Got 390 / 624 correct (62.50)
# Training Accuracy: 0.75, Validation Accuracy: 0.75
# Epoch 2, Iteration 50, loss = 0.3558
# Checking accuracy training
# Got 3468 / 4228 correct (82.02)
# Checking accuracy validation
# Got 862 / 1058 correct (81.47)
# Checking accuracy test
# Got 477 / 624 correct (76.44)
# Training Accuracy: 0.82, Validation Accuracy: 0.81
# Epoch 2, Iteration 100, loss = 0.1956
# Checking accuracy training
# Got 3769 / 4228 correct (89.14)
# Checking accuracy validation
# Got 926 / 1058 correct (87.52)
# Checking accuracy test
# Got 484 / 624 correct (77.56)
# Training Accuracy: 0.89, Validation Accuracy: 0.88
# Epoch 3, Iteration 50, loss = 0.1809
# Checking accuracy training
# Got 3916 / 4228 correct (92.62)
# Checking accuracy validation
# Got 966 / 1058 correct (91.30)
# Checking accuracy test
# Got 496 / 624 correct (79.49)
# Training Accuracy: 0.93, Validation Accuracy: 0.91
# Epoch 3, Iteration 100, loss = 0.1461
# Checking accuracy training
# Got 3928 / 4228 correct (92.90)
# Checking accuracy validation
# Got 974 / 1058 correct (92.06)
# Checking accuracy test
# Got 485 / 624 correct (77.72)
# Training Accuracy: 0.93, Validation Accuracy: 0.92
# Epoch 4, Iteration 50, loss = 0.0798
# Checking accuracy training
# Got 3797 / 4228 correct (89.81)
# Checking accuracy validation
# Got 932 / 1058 correct (88.09)
# Checking accuracy test
# Got 521 / 624 correct (83.49)
# Training Accuracy: 0.90, Validation Accuracy: 0.88
# Epoch 4, Iteration 100, loss = 0.1757
# Checking accuracy training
# Got 3885 / 4228 correct (91.89)
# Checking accuracy validation
# Got 967 / 1058 correct (91.40)
# Checking accuracy test
# Got 432 / 624 correct (69.23)
# Training Accuracy: 0.92, Validation Accuracy: 0.91
# Epoch 5, Iteration 50, loss = 0.3263
# Checking accuracy training
# Got 3889 / 4228 correct (91.98)
# Checking accuracy validation
# Got 946 / 1058 correct (89.41)
# Checking accuracy test
# Got 505 / 624 correct (80.93)
# Training Accuracy: 0.92, Validation Accuracy: 0.89
# Epoch 5, Iteration 100, loss = 0.1840
# Checking accuracy training
# Got 3958 / 4228 correct (93.61)
# Checking accuracy validation
# Got 963 / 1058 correct (91.02)
# Checking accuracy test
# Got 486 / 624 correct (77.88)
# Training Accuracy: 0.94, Validation Accuracy: 0.91
# Epoch 6, Iteration 50, loss = 0.0645
# Checking accuracy training
# Got 3995 / 4228 correct (94.49)
# Checking accuracy validation
# Got 998 / 1058 correct (94.33)
# Checking accuracy test
# Got 457 / 624 correct (73.24)
# Training Accuracy: 0.94, Validation Accuracy: 0.94
# Epoch 6, Iteration 100, loss = 0.1436
# Checking accuracy training
# Got 3970 / 4228 correct (93.90)
# Checking accuracy validation
# Got 993 / 1058 correct (93.86)
# Checking accuracy test
# Got 442 / 624 correct (70.83)
# Training Accuracy: 0.94, Validation Accuracy: 0.94
# Epoch 7, Iteration 50, loss = 0.1686
# Checking accuracy training
# Got 4010 / 4228 correct (94.84)
# Checking accuracy validation
# Got 991 / 1058 correct (93.67)
# Checking accuracy test
# Got 473 / 624 correct (75.80)
# Training Accuracy: 0.95, Validation Accuracy: 0.94
# Epoch 7, Iteration 100, loss = 0.0316
# Checking accuracy training
# Got 4035 / 4228 correct (95.44)
# Checking accuracy validation
# Got 991 / 1058 correct (93.67)
# Checking accuracy test
# Got 468 / 624 correct (75.00)
# Training Accuracy: 0.95, Validation Accuracy: 0.94
# Epoch 8, Iteration 50, loss = 0.1380
# Checking accuracy training
# Got 4007 / 4228 correct (94.77)
# Checking accuracy validation
# Got 970 / 1058 correct (91.68)
# Checking accuracy test
# Got 485 / 624 correct (77.72)
# Training Accuracy: 0.95, Validation Accuracy: 0.92
# Epoch 8, Iteration 100, loss = 0.1886
# Checking accuracy training
# Got 4050 / 4228 correct (95.79)
# Checking accuracy validation
# Got 1005 / 1058 correct (94.99)
# Checking accuracy test
# Got 453 / 624 correct (72.60)
# Training Accuracy: 0.96, Validation Accuracy: 0.95
# Epoch 9, Iteration 50, loss = 0.0160
# Checking accuracy training
# Got 4032 / 4228 correct (95.36)
# Checking accuracy validation
# Got 1000 / 1058 correct (94.52)
# Checking accuracy test
# Got 464 / 624 correct (74.36)
# Training Accuracy: 0.95, Validation Accuracy: 0.95
# Epoch 9, Iteration 100, loss = 0.0906
# Checking accuracy training
# Got 4048 / 4228 correct (95.74)
# Checking accuracy validation
# Got 997 / 1058 correct (94.23)
# Checking accuracy test
# Got 489 / 624 correct (78.37)
# Training Accuracy: 0.96, Validation Accuracy: 0.94
# Checking accuracy final test
# Got 486 / 624 correct (77.88)
# Final Test Accuracy: 0.78

# %% [markdown]
# ### Visualize the Accuracy Over Epochs

# %%
actual_epochs = len(train_accuracies)  # Assuming this reflects the actual number of epochs run
epochs = [i / 2 for i in range(0, actual_epochs)]

# Now, we'll plot the accuracies.
plt.figure(figsize=[10,5])
plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='o')
plt.plot(epochs, test_accuracies, label='Test Accuracy', marker='o')
plt.title('Model Accuracies per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Transfer Learning Resnet 18

# %% [markdown]
# ### Set up transfer learning using resnet 18

# %%
from torchvision import models
from torch.optim import lr_scheduler
model_resnet18 = models.resnet18(weights = models.ResNet18_Weights.DEFAULT)
number_features = model_resnet18.fc.in_features
model_resnet18.fc = nn.Linear(number_features, 2) # change the output to 2 features for binary classificaiton

# %% [markdown]
# Can we fine-tune the last few layers?

# %%
# Freeze all layers
for param in model_resnet18.parameters():
    param.requires_grad = False

# Unfreeze some layers
unfreeze_layers = ['layer4.1.conv1.weight', 'layer4.1.bn1.weight', 'layer4.1.bn1.bias', 'layer4.1.conv2.weight', 'layer4.1.bn2.weight', 'layer4.1.bn2.bias', 'fc.weight', 'fc.bias']
for name, param in model_resnet18.named_parameters():
    if name in unfreeze_layers:
        param.requires_grad = True
        
model_resnet18 = model_resnet18.to(device)

# %%
num_classes = 2  # Normal, Pneumonia
learning_rate = 0.0001
num_epochs = 10

# Optimizer
optimizer = optim.Adam(model_resnet18.parameters(), lr=learning_rate)

# Train the model
train_accuracies, val_accuracies, test_accuracies = train_test_model(model_resnet18,
                                                     train_data_loader,
                                                     val_data_loader, 
                                                     test_data_loader, 
                                                     optimizer, 
                                                     epochs=num_epochs,
                                                     print_every=50,
                                                     device='cuda',
                                                     use_early_stop=True,
                                                     patience=5, 
                                                     use_scheduler=True)
# Out:
# Epoch 0, Iteration 50, loss = 0.0819
# Checking accuracy training
# Got 4133 / 4228 correct (97.75)
# Checking accuracy validation
# Got 1025 / 1058 correct (96.88)
# Checking accuracy test
# Got 512 / 624 correct (82.05)
# Training Accuracy: 0.98, Validation Accuracy: 0.97
# Epoch 0, Iteration 100, loss = 0.0216
# Checking accuracy training
# Got 4143 / 4228 correct (97.99)
# Checking accuracy validation
# Got 1028 / 1058 correct (97.16)
# Checking accuracy test
# Got 509 / 624 correct (81.57)
# Training Accuracy: 0.98, Validation Accuracy: 0.97
# Epoch 1, Iteration 50, loss = 0.0367
# Checking accuracy training
# Got 4158 / 4228 correct (98.34)
# Checking accuracy validation
# Got 1026 / 1058 correct (96.98)
# Checking accuracy test
# Got 513 / 624 correct (82.21)
# Training Accuracy: 0.98, Validation Accuracy: 0.97
# Epoch 1, Iteration 100, loss = 0.0131
# Checking accuracy training
# Got 4173 / 4228 correct (98.70)
# Checking accuracy validation
# Got 1030 / 1058 correct (97.35)
# Checking accuracy test
# Got 510 / 624 correct (81.73)
# Training Accuracy: 0.99, Validation Accuracy: 0.97
# Epoch 2, Iteration 50, loss = 0.0842
# Checking accuracy training
# Got 4180 / 4228 correct (98.86)
# Checking accuracy validation
# Got 1037 / 1058 correct (98.02)
# Checking accuracy test
# Got 494 / 624 correct (79.17)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 2, Iteration 100, loss = 0.0491
# Checking accuracy training
# Got 4189 / 4228 correct (99.08)
# Checking accuracy validation
# Got 1034 / 1058 correct (97.73)
# Checking accuracy test
# Got 500 / 624 correct (80.13)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 3, Iteration 50, loss = 0.0135
# Checking accuracy training
# Got 4183 / 4228 correct (98.94)
# Checking accuracy validation
# Got 1039 / 1058 correct (98.20)
# Checking accuracy test
# Got 504 / 624 correct (80.77)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 3, Iteration 100, loss = 0.1259
# Checking accuracy training
# Got 4198 / 4228 correct (99.29)
# Checking accuracy validation
# Got 1034 / 1058 correct (97.73)
# Checking accuracy test
# Got 472 / 624 correct (75.64)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 4, Iteration 50, loss = 0.0076
# Checking accuracy training
# Got 4184 / 4228 correct (98.96)
# Checking accuracy validation
# Got 1033 / 1058 correct (97.64)
# Checking accuracy test
# Got 480 / 624 correct (76.92)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 4, Iteration 100, loss = 0.0061
# Checking accuracy training
# Got 4201 / 4228 correct (99.36)
# Checking accuracy validation
# Got 1032 / 1058 correct (97.54)
# Checking accuracy test
# Got 500 / 624 correct (80.13)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 5, Iteration 50, loss = 0.0049
# Checking accuracy training
# Got 4202 / 4228 correct (99.39)
# Checking accuracy validation
# Got 1038 / 1058 correct (98.11)
# Checking accuracy test
# Got 503 / 624 correct (80.61)
# Training Accuracy: 0.99, Validation Accuracy: 0.98
# Epoch 5, Iteration 100, loss = 0.0263
# Checking accuracy training
# Got 4164 / 4228 correct (98.49)
# Checking accuracy validation
# Got 1023 / 1058 correct (96.69)
# Checking accuracy test
# Got 530 / 624 correct (84.94)
# Early stopping triggered after 6 epochs.
# Checking accuracy final test
# Got 530 / 624 correct (84.94)
# Final Test Accuracy: 0.85

# %% [markdown]
# ### Visualize the Accuracy Over Epochs

# %%
actual_epochs = len(train_accuracies)  # Assuming this reflects the actual number of epochs run
epochs = [i / 2 for i in range(0, actual_epochs)]

# Now, we'll plot the accuracies.
plt.figure(figsize=[10,5])
plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='o')
plt.plot(epochs, test_accuracies, label='Test Accuracy', marker='o')
plt.title('Model Accuracies per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### How would the model perform if we retrain all layers?

# %%
for name, param in model_resnet18.named_parameters():
    param.requires_grad = True

num_classes = 2  # Normal, Pneumonia
learning_rate = 0.00001
num_epochs = 10

# Optimizer
optimizer = optim.Adam(model_resnet18.parameters(), lr=learning_rate)

# Train the model
train_accuracies, val_accuracies, test_accuracies = train_test_model(model_resnet18,
                                                     train_data_loader,
                                                     val_data_loader, 
                                                     test_data_loader, 
                                                     optimizer, 
                                                     epochs=num_epochs,
                                                     print_every=50,
                                                     device='cuda',
                                                     use_early_stop=True,
                                                     patience=7, 
                                                     use_scheduler=False)
# Out:
# Epoch 0, Iteration 50, loss = 0.0195
# Checking accuracy training
# Got 4212 / 4228 correct (99.62)
# Checking accuracy validation
# Got 1048 / 1058 correct (99.05)
# Checking accuracy test
# Got 487 / 624 correct (78.04)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 0, Iteration 100, loss = 0.0027
# Checking accuracy training
# Got 4211 / 4228 correct (99.60)
# Checking accuracy validation
# Got 1048 / 1058 correct (99.05)
# Checking accuracy test
# Got 493 / 624 correct (79.01)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 1, Iteration 50, loss = 0.0014
# Checking accuracy training
# Got 4218 / 4228 correct (99.76)
# Checking accuracy validation
# Got 1049 / 1058 correct (99.15)
# Checking accuracy test
# Got 490 / 624 correct (78.53)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 1, Iteration 100, loss = 0.0018
# Checking accuracy training
# Got 4180 / 4228 correct (98.86)
# Checking accuracy validation
# Got 1027 / 1058 correct (97.07)
# Checking accuracy test
# Got 528 / 624 correct (84.62)
# Training Accuracy: 0.99, Validation Accuracy: 0.97
# Epoch 2, Iteration 50, loss = 0.0215
# Checking accuracy training
# Got 4217 / 4228 correct (99.74)
# Checking accuracy validation
# Got 1051 / 1058 correct (99.34)
# Checking accuracy test
# Got 482 / 624 correct (77.24)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 2, Iteration 100, loss = 0.0005
# Checking accuracy training
# Got 4219 / 4228 correct (99.79)
# Checking accuracy validation
# Got 1049 / 1058 correct (99.15)
# Checking accuracy test
# Got 497 / 624 correct (79.65)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 3, Iteration 50, loss = 0.0015
# Checking accuracy training
# Got 4224 / 4228 correct (99.91)
# Checking accuracy validation
# Got 1053 / 1058 correct (99.53)
# Checking accuracy test
# Got 497 / 624 correct (79.65)
# Training Accuracy: 1.00, Validation Accuracy: 1.00
# Epoch 3, Iteration 100, loss = 0.0036
# Checking accuracy training
# Got 4222 / 4228 correct (99.86)
# Checking accuracy validation
# Got 1051 / 1058 correct (99.34)
# Checking accuracy test
# Got 480 / 624 correct (76.92)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 4, Iteration 50, loss = 0.0035
# Checking accuracy training
# Got 4224 / 4228 correct (99.91)
# Checking accuracy validation
# Got 1053 / 1058 correct (99.53)
# Checking accuracy test
# Got 487 / 624 correct (78.04)
# Training Accuracy: 1.00, Validation Accuracy: 1.00
# Epoch 4, Iteration 100, loss = 0.0125
# Checking accuracy training
# Got 4218 / 4228 correct (99.76)
# Checking accuracy validation
# Got 1049 / 1058 correct (99.15)
# Checking accuracy test
# Got 457 / 624 correct (73.24)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 5, Iteration 50, loss = 0.0033
# Checking accuracy training
# Got 4223 / 4228 correct (99.88)
# Checking accuracy validation
# Got 1049 / 1058 correct (99.15)
# Checking accuracy test
# Got 502 / 624 correct (80.45)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 5, Iteration 100, loss = 0.0005
# Checking accuracy training
# Got 4225 / 4228 correct (99.93)
# Checking accuracy validation
# Got 1053 / 1058 correct (99.53)
# Checking accuracy test
# Got 484 / 624 correct (77.56)
# Training Accuracy: 1.00, Validation Accuracy: 1.00
# Epoch 6, Iteration 50, loss = 0.0008
# Checking accuracy training
# Got 4227 / 4228 correct (99.98)
# Checking accuracy validation
# Got 1052 / 1058 correct (99.43)
# Checking accuracy test
# Got 489 / 624 correct (78.37)
# Training Accuracy: 1.00, Validation Accuracy: 0.99
# Epoch 6, Iteration 100, loss = 0.0004
# Checking accuracy training
# Got 4219 / 4228 correct (99.79)
# Checking accuracy validation
# Got 1052 / 1058 correct (99.43)
# Checking accuracy test
# Got 459 / 624 correct (73.56)
# Early stopping triggered after 7 epochs.
# Checking accuracy final test
# Got 459 / 624 correct (73.56)
# Final Test Accuracy: 0.74

# %% [markdown]
# ### Visualize the Accuracy Over Epochs

# %%
actual_epochs = len(train_accuracies)  # Assuming this reflects the actual number of epochs run
epochs = [i / 2 for i in range(0, actual_epochs)]

# Now, we'll plot the accuracies.
plt.figure(figsize=[10,5])
plt.plot(epochs, train_accuracies, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracies, label='Validation Accuracy', marker='o')
plt.plot(epochs, test_accuracies, label='Test Accuracy', marker='o')
plt.title('Model Accuracies per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
